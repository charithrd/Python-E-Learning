# %% [markdown]
# <a href="https://colab.research.google.com/github/charithrd/Python-E-Learning/blob/main/T4_Data_Visualisation_In_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![data_assembly.png](data:image/png;base64,...)

# %% [markdown]
# <h3><font color="#AA00BB">How you can use this Notebook</font></h3>
# <p>This notebook was written to teach new concepts in data using Python.</p>
# <p>You can read through the descriptions run the code (it should work!), or you may be taken through the code by one of our experts.</p>
# <p>But one of the best habits to acquire is to re-write the code yourself.</p>
# <ul><li>Experiment
# <li>Break the code
# <li>Build a deeper understanding of both the underlying data concepts and the code</ul>
# <p>Don't worry if you make mistakes, we all do. The way to get better and make less mistakes is to write more code.</p>
# <p>Enjoy!</p>
# <p> - <i><font color="#AA00BB">Data Assembly team.</font></i></p>
# <br>
#
# > ❓🤔 = a question for us discuss
#
# > ⌨️ = a task for you to try
#
# > 🔑 = an authoritative reference or guide you may find useful
#
# > 🚀 = **optional** material to develop yourself further

# %% [markdown]
# <a name="contents"></a>
# ## Contents
#
# <br>1. [Basics of HTML & URL Hacking](#section_1)
# <br>2. [Introduction to XPath](#section_2)
# <br>3. [Beautiful Soup](#section_3)
# <br>4. [Creating Web Crawlers using Scrapy](#section_4)
# <br>5. [Web Scraping using Selenium](#section_4)
# <br>6. [🚀Final Exercise](#section_5)

# %% [markdown]
# <h2><font color="#AA00BB">Welcome to our workbook on Data Visualisation in Python</font></h2>
#
# Welcome to this tutorial on data visualisation using Matplotlib, Seaborn, and Plotly! We'll be learning about the power and versatility of these tools for creating meaningful visualisations that can help us understand and interpret data better.
#
# Let's start learning how to visualise data in Python! 📈
#
# How this lesson is structured:
# - We'll first do a brief introduction to the topic.
# - Next we'll explore the core concepts of ploting using the selected python library.
# - In the exercise we'll use some FitConstructor datasets to create your very own plots in Python.

# %% [markdown]
# # **1. Introduction to Matplotlib**
# [Return to contents](#contents)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Brief History of Matplotlib**
#
# Matplotlib is a plotting library for Python. It was created by John D. Hunter in 2002. Initially designed to allow scientists and researchers to visualise their data in a straightforward and easy way, it has now become a standard library for data visualisation in Python. Matplotlib is open-source and supported by a large community of contributors.
#
# **Why is Matplotlib Important in Data Visualisation?**
#
# Data visualisation is a critical skill for anyone who deals with data. Visuals make it easier to understand the patterns, trends, and insights in datasets. Matplotlib is important because:
#
# - **Flexibility:** It is incredibly flexible, allowing you to create a wide variety of plots and figures.
# - **Ease of Use:** It integrates well with Python and its numerical math libraries like NumPy and pandas.
# - **Community Support:** Being open-source, it has a strong community support.
#
# **Installation and Setup** (already installed in Colab)
#
# Before we dive into plotting, you'll need to install
# ```
# pip install matplotlib
# ```
#
#
#
#
#
# 🔑Learn more at https://matplotlib.org/stable/tutorials/index

# %% [markdown]
# ## **1.1 Let's create your first Matplotlib plot!**
#
# Importing Matplotlib.
#
#
#
# ```
# import matplotlib.pyplot as plt
# ```
#
# - **import**: This is a Python keyword used to import modules into your script.
# - **matplotlib.pyplot**: matplotlib is the package you're importing from, and pyplot is a submodule that provides a convenient interface for plotting.
# - **as plt**: This is an alias. Instead of writing matplotlib.pyplot every time you call a function, you only need to write plt.

# %% [markdown]
# ### **1.1.1 Visualising the Titantic Dataset**
#
# The Titanic dataset provides historical data on the passengers aboard the RMS Titanic, the British luxury liner that sank on its maiden voyage in 1912. The dataset includes various details such as age, fare, class, and survival status, making it a popular resource for data analysis and machine learning exercises.
#
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# Loading our titantic dataset CSV
titanic = pd.read_csv('https://raw.githubusercontent.com/BPP-Digital-Advanced-Data-Analytics/public_datasets/main/titanic.csv')

titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
import matplotlib.pyplot as plt

# Get the number of passengers who survived and did not survive
# titanic['survived'] == 1: This part filters the dataset to include only the
# rows where the 'survived' column has a value of 1, meaning the passenger survived.
# shape[0]: This part tells us the number of rows in the filtered dataset, which gives us the total number of survivors.
n_survived = titanic[titanic['survived'] == 1].shape[0]
n_not_survived = titanic[titanic['survived'] == 0].shape[0]

# Create a bar chart
plt.bar(['Survived', 'Did not survive'], [n_survived, n_not_survived])

# Set the title and labels
plt.title('Titanic Survival Rates')
plt.xlabel('Survival')
plt.ylabel('Number of passengers')

# Show the plot
plt.show()

# %% [markdown]
# ## **1.2 Anatomy of a Matplotlib plot**
#
# A Matplotlib plot consists of the following components:
#
# - **Figure**: The figure is the canvas on which the plot is drawn.
# - **Axes**: The axes are the horizontal and vertical lines that define the coordinate system of the plot.
# - **Ticks**: The ticks are the marks on the axes that indicate the values of the data.
# - **Labels**: The labels are the text that describes the axes and ticks.
# - **Title**: The title is the text that appears at the top of the plot.
# - **Legend**: The legend is a box that identifies the different lines or points in the plot.

# %% [markdown]
# The `plt.bar()` function is used to create a bar chart. The first argument to the `plt.bar()` function is a list of strings that represent the categories on the x-axis. The second argument is a list of numbers that represent the values on the y-axis.
#
# The `plt.title(), plt.xlabel()`, and `plt.ylabel(`) functions are used to set the title, x-axis label, and y-axis label of the plot, respectively.
#
# The `plt.show() `function is used to display the plot.

# %% [markdown]
# ## **1.3 Customisng Matplotlib Plots**
#
# One of the great things about Matplotlib is the ability to extensively customise plots. In this section we will learn how to:
#
# - Change colors and transparency
# - Adjust line style and width
# - Add custom labels
# - Control axis ticks and limits
# - Add annotations like arrows, text boxes, etc
# - Change figure size and aspect ratio

# %%
import matplotlib.pyplot as plt

# Get counts of survivors vs non-survivors
n_survived = titanic[titanic['survived'] == 1].shape[0]
n_not_survived = titanic[titanic['survived'] == 0].shape[0]

# Create bar chart
plt.bar(['Survived', 'Did not survive'], [n_survived, n_not_survived],
color=['g', 'r'], # Set colors
alpha=0.5, # Set transparency
linewidth=2) # Set bar linewidth

# Customize tick locations and labels
plt.xticks([0,1], ['Survived', 'Did not survive'], rotation=90)
plt.yticks(range(0,2000, 500))

# Add labels and title
plt.title('Titanic Survival Rates')
plt.xlabel('Survival')
plt.ylabel('Number of passengers')

# Show plot
plt.show()

# %% [markdown]
# #### **Note**
#
# The (x,y) coordinates for annotations and text correspond to the data limits, not pixels. So (0, 500) means "at x=0, y=500" based on the axes data values. This allows positioning relative to the data.

# %% [markdown]
# ## **⌨️Exercise**
#
# 1. Take the following code and fill in the blanks or incomplete code (😐) to create a simple line plot.
#
#
#
# ```
# import matplotlib.pyplot as plt
#
# # Plot data
# plt.plot([0, 1, 2, 3, 4], [0, 1, 4, 9, 16])
#
# # Add title and labels
# plt.title("BLANK😐...
# plt.xlabel("x")
# plt.ylabel("y")
#
# ## Show plot
# plt.BLANK😐
#
# ```
#
# 2. Add at least 2 customisations to the above plot.

# %%
import matplotlib.pyplot as plt

# Create the figure and axis with a custom background color
fig, ax = plt.subplots(facecolor='lightgray')

# Plot data with green line color, dashed line, and circle markers
plt.plot([0, 1, 2, 3, 4], [0, 1, 4, 9, 16], color='green', linestyle='--', marker='o', markersize=10, markerfacecolor='red')


# Add title and labels with customized font sizes
plt.title("Customized Line Graph", fontsize=16, fontweight='bold')
plt.xlabel("x-axis", fontsize=12)
plt.ylabel("y-axis", fontsize=12)

# Add gridlines
plt.grid(True, which='both', linestyle=':', color='gray')

# Add axis limits
plt.xlim(0, 4.5)
plt.ylim(0, 18)

# Customize ticks
plt.xticks(fontsize=10, rotation=45)  # Rotated x-ticks
plt.yticks(fontsize=10)

# Add a legend with a shadow effect and customized location
plt.legend(['y = x^2'], loc='upper left', shadow=True)

## Show plot
plt.show()

# %% [markdown]
# #**2. Subplots and Basic Plot types**
#
# ## **2.1 Matplotlib Plotting Interfaces**
#
# Matplotlib provides two main ways to create plots:
# 1. **Pyplot interface**
# 2. **Object-oriented interface**
#
# We'll compare these approaches by creating a bar chart of Titanic survival rates by gender.
#
# ### **Pyplot Interface**
#
# The pyplot interface provides simple plotting functions for common chart types.
#
# We can create a bar chart with just a few lines:

# %%
import matplotlib.pyplot as plt

females = titanic[titanic['sex']=='female']
males = titanic[titanic['sex']=='male']

f_survived = sum(females['survived']) / len(females)
m_survived = sum(males['survived']) / len(males)

plt.bar(['Female','Male'], [f_survived, m_survived])
plt.title('Survival Rates by Gender')
plt.show()

# %% [markdown]
# The pyplot interface is great for quick visualization and plotting. But it has limited customization options.
#
# ### **Using fig, ax (Object-oriented interface)**
#
# The object-oriented interface allows full control by directly instantiating figure and axes objects.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create figure and axes
fig, ax = plt.subplots()

# Get data for females and males
females = titanic[titanic['sex']=='female']
males = titanic[titanic['sex']=='male']

# Calculate survival rates
f_survived = sum(females['survived']) / len(females)
m_survived = sum(males['survived']) / len(males)

# Create bar chart
ax.bar(['Female','Male'], [f_survived, m_survived])

# Add title and axis labels
ax.set_title('Survival Rates by Gender')
ax.set_xlabel('Gender')
ax.set_ylabel('Survival Rate')

# Set y-axis limits
ax.set_ylim(0,1)

# Add grid lines
ax.grid(axis='y', linestyle='--')

# Show the figure
fig.tight_layout()
fig.show()

# %% [markdown]
# In this object-oriented approach we first create the figure and axes objects. We then call methods on the axes to plot data, set titles, axis labels, etc. This gives full control over the chart creation and customisation.
#
# The object-oriented interface requires more code but enables crafting a plot exactly how you want it. The pyplot approach is better for quick and simple visualization.

# %% [markdown]
# ### **Example of the customaisations enable using fig, ax (Object-oriented interface)**

# %%
import matplotlib.pyplot as plt

# Get counts of survivors vs non-survivors
n_survived = titanic[titanic['survived'] == 1].shape[0]
n_not_survived = titanic[titanic['survived'] == 0].shape[0]

# Create figure and axes
fig, ax = plt.subplots(figsize=(6,4))

# Create bar chart
ax.bar(['Survived', 'Did not survive'], [n_survived, n_not_survived],
       color=['g', 'r'],        # Set colors
       alpha=0.5,               # Transparency
       linewidth=2,             # Line width
       edgecolor='k')           # Black edges

# Customize grid lines
ax.grid(axis='y', linestyle='--')

# Customize tick locations and labels
ax.set_xticks([0,1])
ax.set_xticklabels(['Survived', 'Did not survive'], rotation=90)
ax.set_yticks(range(0,2000, 500))

# Add annotated arrow
ax.annotate('500 passengers', xy=(0,500), xytext=(0.5,450),
            arrowprops=dict(facecolor='black'))

# Add text box
ax.text(0, 1900, 'Around 1500 died',
        bbox=dict(facecolor='red', alpha=0.5))

# Add labels and title
ax.set_title('Titanic Survival Rates')
ax.set_xlabel('Survival')
ax.set_ylabel('Number of passengers')

# Show plot
plt.show()

# %% [markdown]
# ## **2.2 Introducing Subplots and Plotting Interfaces**
#
# Matplotlib offers two main types of plotting interfaces: the pyplot interface, which provides a simple way to add plots, text, and lines to the current axes in an easy-to-use manner; and the object-oriented interface, which gives you full control over creating and customising figures and axes. In addition to single plots, Matplotlib enables you to create subplots within a figure, allowing for complex layouts and multiple charts in one display.

# %%
# Survival by gender
females = titanic[titanic['sex'] == 'female']
males = titanic[titanic['sex'] == 'male']

f_survived = sum(females['survived']) / females.shape[0]
m_survived = sum(males['survived']) / males.shape[0]

# Plot survival rates
plt.bar(['Female','Male'], [f_survived, m_survived])
plt.title('Survival Rates By Gender')
# Out:
# Text(0.5, 1.0, 'Survival Rates By Gender')

# %%
# Survival by class
class1 = titanic[titanic['pclass'] == 1]
class2 = titanic[titanic['pclass'] == 2]
class3 = titanic[titanic['pclass'] == 3]

c1_survived = sum(class1['survived']) / class1.shape[0]
c2_survived = sum(class2['survived']) / class2.shape[0]
c3_survived = sum(class3['survived']) / class3.shape[0]

# Plot survival rates
plt.bar(['1st Class','2nd Class','3rd Class'], [c1_survived, c2_survived, c3_survived])
plt.title('Survival Rates By Class')
# Out:
# Text(0.5, 1.0, 'Survival Rates By Class')

# %% [markdown]
# ## **Now let's combine them into a single plot (side by side)**

# %%
# Create figure and axes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

# Plot gender survival
ax1.bar(['Female','Male'], [f_survived, m_survived])
ax1.set_title('Survival Rates By Gender')

# Plot class survival
ax2.bar(['1st Class','2nd Class','3rd Class'],
       [c1_survived, c2_survived, c3_survived])
ax2.set_title('Survival Rates By Class')

# Overall title
fig.suptitle('Titanic Survival', fontsize=16)

plt.show()

# %% [markdown]
# #### **Explanation of Subplots with Matplotlib**
#
# - `plt.subplots(1, 2, figsize=(10,5))`: Makes a figure with 1 row and 2 columns of plots. The size is set to 10x5 inches.
# - `fig`: The entire canvas.
# - `(ax1, ax2)`: Two individual plots.
#
# - `ax1.bar(...)`: Makes a bar chart on the first plot (ax1).
# - `ax2.bar(...)`: Makes a bar chart on the second plot (ax2).

# %% [markdown]
# # **2.3 Types of Plots**
#
#
# Matplotlib supports a wide variety of plot types to cater to different data visualisation needs. Here are a few you'll commonly encounter:
#
# - **Line Plots**: Ideal for time series data.
# - **Bar Charts**: Great for showing categorical data.
# - **Histograms**: Useful for visualising frequency distributions.
# - **Scatter Plots**: Perfect for spotting correlations between two variables.
# - **Pie Charts**: Good for representing a part-to-whole relationship.
# These plots can be mixed and matched in subplots, allowing for highly customisable and insightful visual presentations of data.

# %% [markdown]
# ### **Line Plot**
# To display the number of passengers at different fare levels, you can use a line plot.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming titanic_df is your DataFrame
# Remove NaN values and sort DataFrame by 'Age'
sorted_df = titanic.dropna(subset=['age']).sort_values(by='age')

# Calculate cumulative survival rate
sorted_df['Cumulative_Survival_Rate'] = sorted_df['survived'].expanding().mean()

plt.plot(sorted_df['age'], sorted_df['Cumulative_Survival_Rate'])
plt.title('Cumulative Survival Rate by Age')
plt.xlabel('Age')
plt.ylabel('Cumulative Survival Rate')
plt.grid(True)
plt.show()

# %% [markdown]
# #### **Bar Chart**
# To show the survival rates by gender, a bar chart would be appropriate.

# %%
# Calculate survival rate by gender
survival_by_gender = titanic.groupby('sex')['survived'].mean()

plt.bar(survival_by_gender.index, survival_by_gender)
plt.title('Survival Rates by Gender')
plt.xlabel('Gender')
plt.ylabel('Survival Rate')
plt.show()

# %% [markdown]
# #### **Histogram**
# You can use a histogram to see the distribution of ages.

# %%
# Remove NaN values from the 'Age' column
age_data = titanic['age'].dropna()

plt.hist(age_data, bins=20, edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### **Scatter Plot**
# A scatter plot could be used to identify if there's any correlation between age and fare.

# %%
plt.scatter(titanic['age'], titanic['fare'])
plt.title('Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# #### **Pie Chart**
# You can represent the share of passengers in each class with a pie chart.

# %%
# Count passengers by class
class_count = titanic['pclass'].value_counts()

plt.pie(class_count, labels=['3rd Class', '1st Class', '2nd Class'], autopct='%1.1f%%')
plt.title('Passenger Class Distribution')
plt.show()

# %% [markdown]
# ## **⌨️ Exercise**
#
# ![image.png](data:image/png;base64,...)
#
# Using the FitConstructor User Data dataset, perform the following tasks:
#
# Dataset availalbe here - https://raw.githubusercontent.com/BPP-Digital-Advanced-Data-Analytics/public_datasets/main/fitconstructor/user_data.csv
#
# 1. Create a single figure with two subplots side by side.
# 2. In the first subplot, make a Bar Chart showing the average weight (weight_kg) for each gender (gender).
# 3. In the second subplot, make a Histogram to display the distribution of heights (height_cm).
#
# Useful Functions:
#
# - `plt.subplots()`: To create subplots.
# - `ax.bar()`: For the bar chart.
# - `ax.hist()`: For the histogram.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('https://raw.githubusercontent.com/BPP-Digital-Advanced-Data-Analytics/public_datasets/main/fitconstructor/user_data.csv')

# Clean the dataset by selecting relevant columns
data_cleaned = data[['gender', 'weight_kg', 'height_cm']].copy()

# Grouping the data by gender to calculate average weight for each gender
avg_weight_by_gender = data_cleaned.groupby('gender')['weight_kg'].mean()

# Setting up the figure and subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# First subplot: Bar Chart of average weight by gender
ax1.bar(avg_weight_by_gender.index, avg_weight_by_gender.values, color=['blue', 'pink'])
ax1.set_title('Average Weight by Gender')
ax1.set_xlabel('Gender')
ax1.set_ylabel('Average Weight (kg)')

# Second subplot: Histogram of height distribution
ax2.hist(data_cleaned['height_cm'], bins=20, color='green', edgecolor='black')
ax2.set_title('Height Distribution')
ax2.set_xlabel('Height (cm)')
ax2.set_ylabel('Frequency')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # **3. Visualising with Seaborn**
#
# Seaborn provides a high-level interface for creating beautifully styled, complex plots with ease. We'll look at why you might choose Seaborn over Matplotlib, explore basic plots like box and violin plots, and discuss styling options.
#
# Well, Seaborn simplifies many aspects of data visualisation by providing:
#
# 1. Built-in themes and colour palettes for better aesthetics
# 2. Easy integration with Pandas DataFrames
# 3. High-level functions for creating complex statistical plots

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Installation and Importing Seaborn**
#
# First, if you haven't installed Seaborn, you can do so by running:
#
#
# ```
# pip install seaborn
# ```
#
# We then import it by:
#
# ```
# import seaborn as sns
#
# ```
#
# We typically import seaborn using the alias `sns`.

# %% [markdown]
# ### **Using Seaborn to visualise the 'Tips' dataset**
#
# The tips dataset in Seaborn is a dataset containing information about tips left by customers at a restaurant. Here are some key details about what is included in the tips dataset:
#
# - It contains data for 244 tips left by customers
# - Includes the total bill amount for the table
# - Tip amount left by the customer
# - Sex of the customer (Male or Female)
# - Whether the customer was smoking or not (Boolean)
# - Day of the week
# - Time of day (Lunch or Dinner)
# - Size of the party at the table

# %% [markdown]
# ## **Here's a simply barplot in Seaborn.**

# %%
# Import Seaborn
import seaborn as sns
import matplotlib.pyplot as plt

# Load the tips dataset
tips = sns.load_dataset("tips")

# Create a bar plot
sns.barplot(x="day", y="tip", data=tips)

# Add title and labels
plt.title("Average Tip by Day")
plt.xlabel("Day of the Week")
plt.ylabel("Average Tip ($)")

# Display the plot
plt.show()

# %% [markdown]
# **And now here's a boxplot in Seaborn**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the tips dataset
tips = sns.load_dataset('tips')

# Create boxplot
sns.boxplot(x='day', y='tip', data=tips)

# Show plot
plt.show()

# %% [markdown]
# ❓🤔 **What do you notice about the above code?**
#
# We're using **matplotlib** alongside seaborn!
#
# **Why?**
#
# Seaborn is built on top of Matplotlib, offering a higher-level, more user-friendly interface for creating complex visualisations. Using Matplotlib alongside Seaborn allows for greater customisation and fine-tuning of plots. Essentially, Seaborn makes it easy to generate plots quickly, while Matplotlib provides the tools to tweak and customise those plots in detail.

# %% [markdown]
# ### **3.2 Seaborn style and customisation**

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
tips = sns.load_dataset('tips')

# Quick data exploration
print(tips.head())

# Set visual style and colour palette
sns.set_style("whitegrid")
sns.set_palette("pastel")

# Create a stylish boxplot
sns.boxplot(x='day', y='tip', data=tips)

# Add title and labels
plt.title('Boxplot of Tips by Day', fontsize=16)
plt.xlabel('Day of the Week', fontsize=14)
plt.ylabel('Tip Amount ($)', fontsize=14)

# Show the plot
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #### **Style Changes in Seaborn**
#
# - **Setting Style**: `sns.set_style("style_name")`
#   - Sets the background grid style; options include "whitegrid", "darkgrid", "white", etc.
# - **Setting Palette**: `sns.set_palette("palette_name")`
#   - Sets the colour scheme for plots; options include "pastel", "coolwarm", "muted", etc.
# - **Title**: `plt.title('Title Text', fontsize=size)`
#  - Adds a title to the plot with an optional font size.
# - **X and Y Labels**: `plt.xlabel('Label'), plt.ylabel('Label')`
#  - Adds labels to the x-axis and y-axis.

# %% [markdown]
# ### **3.2 Types of Seaborn plots**
#
# Violin plots combine the features of boxplots and kernel density plots, offering a detailed view of the distribution of numerical data.
#
# ![image.png](data:image/png;base64,...)

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
tips = sns.load_dataset('tips')

# Quick data exploration
print(tips.head())

# Set visual style and new colour palette
sns.set_style("whitegrid")
sns.set_palette("coolwarm")

# Create a stylish violin plot
sns.violinplot(x='day', y='tip', data=tips)

# Add title and labels
plt.title('Violin Plot of Tips by Day', fontsize=16)
plt.xlabel('Day of the Week', fontsize=14)
plt.ylabel('Tip Amount ($)', fontsize=14)

# Show the plot
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ❓🤔 What do you notice about the above charts?
#
# There were a few very big tippers on Saturday! but Sunday's you can see the majority of tips in the upper interquartile range is higher than any other day.

# %% [markdown]
# ### **3.3 Custom Colour Palattes**
#
# You can specify colours for individual categories using the palette argument in Seaborn's violinplot function. Here's how you can change the colours for weekend and weekday dates in the violin plot.
#
#
# In this code, the palette argument accepts a dictionary (`custom_palette`) that maps the days of the week to colours ('r' for red and 'g' for green). This way, weekend days ('Sat', 'Sun') will appear in red, and weekdays ('Thur', 'Fri') will appear in green.

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
tips = sns.load_dataset('tips')

# Set visual style
sns.set_style("whitegrid")

# Custom colour palette: Weekend (Sat, Sun) in red, Weekday (Thur, Fri) in green
custom_palette = {'Thur': 'g', 'Fri': 'g', 'Sat': 'r', 'Sun': 'r'}

# Create a stylish violin plot with custom colours
sns.violinplot(x='day', y='tip', data=tips, palette=custom_palette)

# Add title and labels
plt.title('Violin Plot of Tips by Day', fontsize=16)
plt.xlabel('Day of the Week', fontsize=14)
plt.ylabel('Tip Amount ($)', fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# ### **3.4 Combining Multiple Plots**
#
# Combining multiple plot types can add more depth to your data visualisation. In Seaborn, overlaying a swarm plot on top of a violin plot provides a detailed view of both the distribution and individual data points.

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
tips = sns.load_dataset('tips')

# Quick data exploration
print(tips.head())

# Set visual style
sns.set_style("whitegrid")

# Custom colour palette: Weekend (Sat, Sun) in red, Weekday (Thur, Fri) in green
custom_palette = {'Thur': 'g', 'Fri': 'g', 'Sat': 'r', 'Sun': 'r'}

# Create a violin plot with custom colours
sns.violinplot(x='day', y='tip', data=tips, palette=custom_palette, inner=None)

# Overlay a swarm plot
sns.swarmplot(x='day', y='tip', data=tips, color='k', alpha=0.6)

# Add title and labels
plt.title('Violin and Swarm Plot of Tips by Day', fontsize=16)
plt.xlabel('Day of the Week', fontsize=14)
plt.ylabel('Tip Amount ($)', fontsize=14)

# Show the plot
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# - **Violin Plot:** Created using sns.violinplot(). We use the inner=None parameter to remove the inner bars within the violins.
#
# - **Swarm Plot**: Created using sns.swarmplot(). This adds individual data points on top of the violin plot. The color='k' argument sets the colour of the swarm plot to black, and alpha=0.6 makes the points slightly transparent.
#
# - **Overlaying**: Both the violin and swarm plots share the same x and y axes, so they are automatically overlaid when plotted in sequence.
#
# - **Palette**: We use the custom_palette dictionary to control the colours of the violin plot, making weekends red and weekdays green.

# %% [markdown]
# ## **⌨️ Exercise**
#
# ![image.png](data:image/png;base64,...)
#
# Using this FitConstructor dataset (see link below), complete at least 3 of the 5 questions below.
#
# https://raw.githubusercontent.com/BPP-Digital-Advanced-Data-Analytics/public_datasets/main/fitconstructor/crm_user.csv
#
#
# 1. **Bar Plot for Gender Distribution**: Create a bar plot showing the distribution of genders in the dataset. Use different colours for male and female.
#
# 2. **Swarm Plot Overlay:** Create a violin plot to show the distribution of height_cm for both genders. Overlay a swarm plot on top of it.
#
# 3. **Custom Style**: Take your plot from question 2 and apply a custom style and palette. Make sure to add titles and axis labels.
#
# 4. **Source of Customers**: Create a pie chart to show the proportion of customers coming from different original_source like 'offline' and 'direct'.
#
# 5. **Combine Plots**: Create a subplot containing two plots. The first should be a bar plot showing the average weight_kg for each gender. The second should be a scatter plot comparing height_cm and weight_kg.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import matplotlib.gridspec as gridspec

# Load the dataset
data = pd.read_csv("https://raw.githubusercontent.com/BPP-Digital-Advanced-Data-Analytics/public_datasets/main/fitconstructor/crm_user.csv")

# Preview the dataset
data.head()

# 1. Bar Plot for Gender Distribution
plt.figure(figsize=(8, 5))
# Define the complete palette to include 'unknown'
palette = {'male': 'skyblue', 'female': 'lightpink', 'unknown': 'gray'}
sns.countplot(x='gender', data=data, hue='gender', palette=palette, legend=False)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# 2. Swarm Plot Overlay on Violin Plot
plt.figure(figsize=(10, 6))
sns.violinplot(x='gender', y='height_cm', data=data, palette='pastel')
sns.swarmplot(x='gender', y='height_cm', data=data, color='k', alpha=0.6)
plt.title('Distribution of Height by Gender with Swarm Overlay')
plt.xlabel('Gender')
plt.ylabel('Height (cm)')
plt.show()

# 3. Custom Style and Palette for Violin + Swarm Plot
plt.figure(figsize=(10, 6))
sns.set(style='whitegrid')  # Custom style
sns.violinplot(x='gender', y='height_cm', data=data, palette='coolwarm')
sns.swarmplot(x='gender', y='height_cm', data=data, color='black', alpha=0.7)
plt.title('Height Distribution by Gender (Custom Style)')
plt.xlabel('Gender')
plt.ylabel('Height in cm')
plt.show()

# 4. Pie Chart for Source of Customers
fig = px.pie(data, names='original_source', title='Proportion of Customers by Source')
fig.show()

# 5. Subplots: Average Weight and Scatter Plot of Height vs Weight
fig = plt.figure(figsize=(14, 6))
gs = gridspec.GridSpec(1, 2, width_ratios=[1, 2])  # Set up grid

# Bar plot for Average Weight per Gender
ax1 = plt.subplot(gs[0])
avg_weight = data.groupby('gender')['weight_kg'].mean().reset_index()
sns.barplot(x='gender', y='weight_kg', data=avg_weight, palette='coolwarm', ax=ax1)
ax1.set_title('Average Weight by Gender')
ax1.set_xlabel('Gender')
ax1.set_ylabel('Average Weight (kg)')

# Scatter plot for Height vs Weight
ax2 = plt.subplot(gs[1])
sns.scatterplot(x='height_cm', y='weight_kg', hue='gender', data=data, palette={'male': 'skyblue', 'female': 'lightpink','unknown': 'gray'}, ax=ax2)
ax2.set_title('Height vs Weight Scatter Plot')
ax2.set_xlabel('Height (cm)')
ax2.set_ylabel('Weight (kg)')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-5dae4c91d426>:25: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <ipython-input-22-5dae4c91d426>:35: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **4. Seaborn - Pairplots, Heatmaps and Facet Grids**
#
# ## **4.1 Let's create a Pairplot**

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the tips dataset
tips = sns.load_dataset("tips")

# Create a pair plot
sns.pairplot(tips, hue='sex')

# Display the plot
plt.show()

# %% [markdown]
# ### **Explanation of Results:**
#
# In the generated pair plot, you'll see scatter plots and histograms:
#
# - **Scatter Plots:** Each scatter plot shows the relationship between two numerical variables in the dataset. For instance, the scatter plot for "total_bill" vs "tip" helps you visually understand how the tip amount varies with the total bill.
#
# - **Kernel Density Estimation (KDE)**: The diagonal shows a KDE plot which gives a smooth curve that provides a sense of the "density" of the data at different values, essentially smoothing out the noise in the data for easier interpretation. For example, you can observe how "total_bill" or "tip" amounts are distributed.
#
# - **Color Hue**: Points are coloured based on the "sex" column, so you can also get an idea of how the variables relate differently for different genders.

# %% [markdown]
# ## **4.2 Now let's create a Heatmap of Correlation Matrix**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the tips dataset
tips = sns.load_dataset("tips")

# Calculate the correlation matrix
correlation_matrix = tips.corr()

# Generate a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

# Display the plot
plt.show()
# Out:
# <ipython-input-22-2c74c6202adf>:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = tips.corr()

# %% [markdown]
# Here, we first calculate the correlation matrix corr for the Iris dataset using the Pandas `.corr()` method. Then, we create a heatmap using sns.`heatmap()`. The `annot=True` parameter adds annotations to each cell, and `cmap='coolwarm'` sets the colour map.

# %% [markdown]
# ### **Interpreting a Correlation Matrix Heatmap Plot**
#
#  A heatmap displays the correlation matrix with colours representing the strength and direction of relationships between numerical variables.
#
# - **Colours**: Warm (red) indicates strong positive correlation; cool (blue) indicates strong negative correlation.
#
# - **Values**: The numbers in the cells are correlation coefficients, ranging from -1 (strong negative) to 1 (strong positive).
#
# For Example:
# - **Total bill** has a strong positive correlation **(0.68)** with **tip size**

# %% [markdown]
# ### **4.3 Facet Grids in Seaborn**

# %% [markdown]
# #### **How to Interpret the Facet Grid:**
#
# - Each row represents a level of the '**sex**' variable (Male or Female).
# - Each column represents a level of the '**time**' variable (Lunch or Dinner).
# - Within each subplot, you see a scatterplot between '**total_bill**' and '**tip**'.
#
# Using this Facet Grid, you can easily compare how tipping behavior varies across different combinations of time and sex.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the tips dataset
tips = sns.load_dataset('tips')

# Create a FacetGrid
g = sns.FacetGrid(tips, col='time', row='sex')

# Map a scatterplot onto each FacetGrid subplot
g.map(sns.scatterplot, 'total_bill', 'tip')

# Show the plots
plt.show()

# %% [markdown]
# ## **⌨️ Exercise**
#
# **Tasks**
# 1. Create a correlation heatmap to understand the relationships between numerical variables like `height_cm`, `weight_kg`, and `number_of_visit`.
# 2. Generate a Pairwise plot (pairplot) to visualize the distributions and correlations of the same numerical variables.
# 3. Use a FacetGrid to plot the distribution of `weight_kg`, segmented by `gender`.
#
#
# **Hints**
# 1. For the correlation heatmap, you can use `sns.heatmap`. Compute the correlation matrix using Pandas' `.corr()` method on the DataFrame.
# 2. For the Pairwise plot, you can use `sns.pairplot`. Select the columns `height_cm`, `weight_kg`, and `number_of_visit` for this plot.
# 3. For the FacetGrid, you can use `sns.FacetGrid` followed by map. Use `weight_kg` for the main variable and `gender` to segment the data.

# %% [markdown]
# # **5. Plotly Visualisations in Python**
#
# Plotly offers **interactive** visualisation capabilities that allow users to zoom, pan, hover, and more. Below, we'll explore scatter and line plots using the gapminder dataset, which contains information about countries over time like GDP, life expectancy, and population.

# %% [markdown]
# To get started with plotly you might have to instal it using pip as follows:
#
#
#
# ```
# pip install plotly
# ```

# %%
import plotly.express as px

# Load the gapminder dataset
df = px.data.gapminder()

# Filter data for the year 2007
df_2007 = df[df['year']==2007]

# Create the scatter plot
fig = px.scatter(df_2007, x='gdpPercap', y='lifeExp', color='continent', hover_name='country', size='pop', size_max=60)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The Plotly library offers a straightforward syntax for creating a wide array of interactive plots. Here's a breakdown of some of the main components of the syntax:
#
# - **plotly.express** is a simple interface to Plotly, which allows you to create most types of plots.
# - **gapminder** is used to load some of the built-in datasets with plotly.
#
# **Explainatin of the Plotly Syntax:**
#
# - `px.scatter(): `This function creates a scatter plot.
# - `df_2007`: The data frame containing the data.
# - `x='gdpPercap'`: The column to be used for the x-axis.
# - `y='lifeExp'`: The column to be used for the y-axis.
# - `color='continent`': Data points will be coloured based on the 'continent' column.
# - `hover_name='country`': Hovering over a point will display the corresponding country name.
# - `size='pop'`: The size of the data points is determined by the 'pop' column.
# - `size_max=60`: Sets the maximum marker size.
# - `fig.show() `method on the fig object will display the plot.

# %% [markdown]
# ### ❓🤔 **Explore the Interactivity Options:**
# - **Hover**: Hovering over a point will display additional information.
# - **Zoom**: Use the scroll wheel to zoom in and out within the plot.
# - **Pan**: Click and drag to move
#
#
#
#  the plot.
# - **Reset**: Double click to reset the zoom and pan settings.
# - **Legend**: Click on the legend to hide/show data series.

# %% [markdown]
# ## **5.2 Simple line plots with Plotly**
#
# For a line plot, let's observe the GDP per capita over time for Japan:

# %%
# Filter data for Japan
df_japan = df[df['country']=='Japan']

# Create the line plot
fig = px.line(df_japan, x='year', y='gdpPercap', title='GDP per Capita Over Time in Japan')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **⌨️ Exercise**
#
# Using this **FitConstructor** dataset (see link below), complete the following task:
#
# https://raw.githubusercontent.com/BPP-Digital-Advanced-Data-Analytics/public_datasets/main/fitconstructor/crm_user.csv
#
# **Tasks:**
# 1. Create a scatter plot using Plotly to visualise the relationship between **height_cm** and **weight_kg**.
# 2. Create a bar chart using Plotly to display the frequency of original_source.
#
# **Hints:**
# 1. For the scatter plot, you can use `plotly.express.scatter`. Use `height_cm` for the x-axis and `weight_kg` for the y-axis.
# 2. For the bar chart, you can use `plotly.express.bar`. Make sure to set the x-axis to original_source and use the count function to get the frequency.

# %% [markdown]
# # **6. 3D Plots, Geographic Maps and Dashboards with Plotly**
#
# Plotly excels at creating interactive 3D plots, geographical maps, and even dashboards. Below are some examples using Python code for each of these types of visualisations.

# %% [markdown]
# ## **6.1 3D Scatter Plot**
#
# In this 3D scatter plot, the x, y, and z axes represent GDP per capita, life expectancy, and population, respectively. The colour represents the continent, and hovering over each point shows the country's name.

# %%
import plotly.express as px

# Using a built-in dataset for demonstration
df = px.data.gapminder().query("year==2007")

# Create a 3D scatter plot
fig_3d = px.scatter_3d(df, x='gdpPercap', y='lifeExp', z='pop', color='continent', hover_name='country')

# Show the plot
fig_3d.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **6.2 Geographical Map**
#
# In this map, each point represents a country, sized by its population and coloured by its continent. The projection="orthographic" option sets the projection style of the map.

# %%
# Create a geographical map plot
fig_map = px.scatter_geo(df, locations="iso_alpha", color="continent",
                          hover_name="country", size="pop", projection="orthographic")

# Show the plot
fig_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### **Explanation of the Geographical Map Plot Code using Plotly**
# - Import Plotly Express: If not already done, import Plotly Express as px to access its methods for plotting.
#
# 1. **Create Geographical Map Plot**: px.scatter_geo() is the function used to create the map. Here, the arguments define several aspects of the plot:
#
# 2. **df**: The DataFrame containing your data.
#  - `locations="iso_alpha"`: Column in the DataFrame indicating the ISO country codes.
#  - `color="continent"`: Color-codes the markers based on the continent.
#  - `hover_name="country"`: The name to display when hovering over a point.
#  - `size="pop"`: Sizes the markers according to the population.
#  - `projection="orthographic"`: Sets the projection type of the map.
# 3. **Show the Plot**: fig_map.show() is used to display the map.

# %% [markdown]
# ## **6.3 Dashboards using Dash and Plotly**
#
# Dash is developed by Plotly and serves as a framework for creating interactive, web-based dashboards using Plotly visualisations.
#
# To install Dash, you can run the following command in your terminal or command prompt:
#
#
# ```
# pip install dash
# ```
# ### **⚠️NOTE - Due to a recent (Nov 2023) update in Google Colab, Dash's dashboards won't display as expected. However, the code below should work on your local machine**

# %%
# !pip install dash
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 21.4 MB/s eta 0:00:00
# ...

# %%
import dash
import dash_core_components as dcc
from dash import html
from dash.dependencies import Input, Output


# Initialise the Dash app
app = dash.Dash(__name__)

# Layout
app.layout = html.Div([
    dcc.Dropdown(
        id='dropdown-input',
        options=[{'label': i, 'value': i} for i in df['continent'].unique()],
        value='Asia'
    ),
    dcc.Graph(id='graph-output')
])

# Callback
@app.callback(
    Output('graph-output', 'figure'),
    [Input('dropdown-input', 'value')]
)
def update_graph(selected_continent):
    filtered_df = df[df['continent'] == selected_continent]
    return px.scatter(filtered_df, x='gdpPercap', y='lifeExp')

# Run the app
if __name__ == '__main__':
    # app.run_server(debug=True)
    app.run_server(mode='inline', host='localhost', port=80)

# %% [markdown]
# ### ❓🤔 **Explore the Interactivity Options on our Dashboard:**
#
# 1. Using the drop down menu and see how the chart updates automatically.
# 2. Hover over points to see the regular plotly interactivity options.

# %% [markdown]
# ### **Explanation of the Dash Dashboard Code**
# - **Import Libraries:** dash, dash_core_components, and dash_html_components are imported to create the web application.
#
# - **Initialise Dash**: dash.Dash(__name__) initiates a new Dash application.
#
# - **Layout**: Defines the layout of the web application. It includes a Dropdown component (dcc.Dropdown) and a Graph component (dcc.Graph).
#
# - **Callback**: The @app.callback decorator specifies that the function below it will be triggered whenever the value of the Dropdown (dropdown-input) changes. The function updates the scatter plot accordingly.
#
# - **Run App**: app.run_server(debug=True) starts the web server, and you can view the dashboard by navigating to the given URL.

# %% [markdown]
# ## **⌨️ Exercise**
#
# Using this **FitConstructor** dataset (see link below), complete the following task:
#
# https://raw.githubusercontent.com/BPP-Digital-Advanced-Data-Analytics/public_datasets/main/fitconstructor/crm_user.csv
#
# **Tasks:**
# 1. Create a 3D scatter plot using Plotly to visualise the relationship between height_cm, weight_kg, and number_of_visit.
# 2. Create a simple bar chart to show the frequency of each original_source.
# 3. Create a simple interactive dashboard using Dash that displays both the 3D scatter plot and the bar chart.
#
# **Hints:**
# - For the 3D scatter plot, consider using plotly.express.scatter_3d.
# - For the bar chart, you can use plotly.express.bar to count the frequency of each original_source.
# - Use Dash's dcc.Graph component to embed Plotly plots in your dashboard.
